# %%
import pandas as pd

# %%
df = pd.read_csv("employees.csv")
df.head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null object
# Start Date           1000 non-null object
# Last Login Time      1000 non-null object
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    933 non-null object
# Team                 957 non-null object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
#Let's optimise the storage
df["Start Date"] = pd.to_datetime(df["Start Date"])
df["Last Login Time"] = pd.to_datetime(df["Last Login Time"])
df["Gender"] = df["Gender"].astype("category")
df["Senior Management"] = df["Senior Management"].astype("bool")

# %%
#We Reduced the space from 63K to 49K
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null category
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.0+ KB

# %%
#Shorter way to parse columns as dates
df = pd.read_csv("employees.csv", parse_dates=["Start Date", "Last Login Time"])
df["Gender"] = df["Gender"].astype("category")
df["Senior Management"] = df["Senior Management"].astype("bool")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2019-11-03 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2019-11-03 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2019-11-03 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %% [markdown]
# ## Filter data based on condition

# %%
#Let's filter data where gender = Male
mask = df["Gender"] == "Male"
mask
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12      True
# 13      True
# 14     False
# 15     False
# 16      True
# 17      True
# 18     False
# 19     False
# 20     False
# 21      True
# 22     False
# 23      True
# 24      True
# 25      True
# 26      True
# 27     False
# 28      True
# 29      True
#        ...
# 970    False
# 971     True
# 972    False
# 973     True
# 974     True
# 975    False
# 976    False
# 977    False
# 978     True
# 979     True
# 980    False
# 981     True
# 982    False
# 983     True
# 984    False
# 985    False
# 986    False
# 987    False
# 988    False
# 989    False
# 990    False
# 991    False
# 992     True
# 993    False
# 994     True
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %%
df[mask].head()
# Out:
#   First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male 1993-08-06 2019-11-03 12:42:00   97308    6.945
# 1     Thomas   Male 1996-03-31 2019-11-03 06:53:00   61933    4.170
# 3      Jerry   Male 2005-03-04 2019-11-03 13:00:00  138705    9.340
# 4      Larry   Male 1998-01-24 2019-11-03 16:47:00  101004    1.389
# 5     Dennis   Male 1987-04-18 2019-11-03 01:35:00  115163   10.125
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 3               True          Finance
# 4               True  Client Services
# 5              False            Legal

# %%
#Let's filter data where Team is not 'Marketing'
mask = df["Team"] != "Marketing"
df[mask].head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1     Thomas    Male 1996-03-31 2019-11-03 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2019-11-03 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2019-11-03 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2019-11-03 16:47:00  101004    1.389
# 5     Dennis    Male 1987-04-18 2019-11-03 01:35:00  115163   10.125
#
#    Senior Management             Team
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services
# 5              False            Legal

# %%
#Let's filter data where Start Date is greater than 2015-07-14
mask = df["Start Date"] > "2015-07-14"
df[mask].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 7         NaN  Female 2015-07-20 2019-11-03 10:43:00   45906   11.598
# 15    Lillian  Female 2016-06-05 2019-11-03 06:09:00   59414    1.256
# 39        NaN    Male 2016-01-29 2019-11-03 02:33:00  122173    7.797
# 89     Janice  Female 2016-03-12 2019-11-03 00:40:00   51082   11.955
# 98       Tina  Female 2016-06-16 2019-11-03 19:47:00  100705   16.961
#
#     Senior Management             Team
# 7                True          Finance
# 15              False          Product
# 39               True  Client Services
# 89              False            Legal
# 98               True        Marketing

# %%
mask = df["Senior Management"] #Since this column is already boolean
df[mask].head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2019-11-03 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2019-11-03 06:53:00   61933    4.170
# 3      Jerry    Male 2005-03-04 2019-11-03 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2019-11-03 16:47:00  101004    1.389
# 6       Ruby  Female 1987-08-17 2019-11-03 16:20:00   65476   10.012
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 3               True          Finance
# 4               True  Client Services
# 6               True          Product

# %% [markdown]
# ## Filter data based on multiple conditions (AND - &, OR - |)

# %%
#Let's filter all the Males having Salary greater than 10,000
mask1 = df["Gender"] == "Male"
mask2 = df["Salary"] > 10000
df[mask1 & mask2].head()
# Out:
#   First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male 1993-08-06 2019-11-03 12:42:00   97308    6.945
# 1     Thomas   Male 1996-03-31 2019-11-03 06:53:00   61933    4.170
# 3      Jerry   Male 2005-03-04 2019-11-03 13:00:00  138705    9.340
# 4      Larry   Male 1998-01-24 2019-11-03 16:47:00  101004    1.389
# 5     Dennis   Male 1987-04-18 2019-11-03 01:35:00  115163   10.125
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 3               True          Finance
# 4               True  Client Services
# 5              False            Legal

# %%
#Let's filter all the employess who either are Senior Management or are a part of Marketing team
mask1 = df["Senior Management"]
mask2 = df["Team"] == "Marketing"

df[mask1 | mask2].head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2019-11-03 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2019-11-03 06:53:00   61933    4.170
# 3      Jerry    Male 2005-03-04 2019-11-03 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2019-11-03 16:47:00  101004    1.389
# 6       Ruby  Female 1987-08-17 2019-11-03 16:20:00   65476   10.012
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 3               True          Finance
# 4               True  Client Services
# 6               True          Product

# %%
#Let's filter data where Males having salary > 1000000 or anyone having Bonus % > 19.8
mask1 = df["Gender"] == "Male"
mask2 = df["Salary"] > 1000000
mask3 = df["Bonus %"] > 19.8

df[(mask1 & mask2) | mask3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 150       Sean    Male 1996-05-04 2019-11-03 20:59:00  135490   19.934
# 335     Robert    Male 2014-11-18 2019-11-03 05:00:00   85799   19.930
# 348     Philip    Male 1989-08-02 2019-11-03 11:21:00  129968   19.897
# 387     Robert    Male 1994-10-29 2019-11-03 04:26:00  123294   19.894
# 488     Robert    Male 2007-03-11 2019-11-03 11:20:00  135882   19.944
# 797       Rose  Female 1982-12-31 2019-11-03 18:50:00  145001   19.850
# 830    Michael    Male 2002-08-31 2019-11-03 01:20:00   81206   19.908
#
#      Senior Management             Team
# 150              False        Marketing
# 335              False          Finance
# 348              False          Finance
# 387              False  Client Services
# 488              False            Legal
# 797              False      Engineering
# 830               True     Distribution

# %% [markdown]
# ## .isin() Method
# - use this method to compare multiple values in the same Series

# %%
#Suppose that we want data where 'Marketing' and 'Finance' teams are involved. Simple approach would be to do
#the following
mask1 = df["Team"] == "Marketing" 
mask2 =  df["Team"] == "Finance"
df[mask1 | mask2].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0     Douglas    Male 1993-08-06 2019-11-03 12:42:00   97308    6.945
# 2       Maria  Female 1993-04-23 2019-11-03 11:17:00  130590   11.858
# 3       Jerry    Male 2005-03-04 2019-11-03 13:00:00  138705    9.340
# 7         NaN  Female 2015-07-20 2019-11-03 10:43:00   45906   11.598
# 14   Kimberly  Female 1999-01-14 2019-11-03 07:13:00   41426   14.543
#
#     Senior Management       Team
# 0                True  Marketing
# 2               False    Finance
# 3                True    Finance
# 7                True    Finance
# 14               True    Finance

# %%
#Let's make it easier
mask = df["Team"].isin(["Marketing", "Finance", "Legal"]) 
df[mask].head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2019-11-03 12:42:00   97308    6.945
# 2      Maria  Female 1993-04-23 2019-11-03 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2019-11-03 13:00:00  138705    9.340
# 5     Dennis    Male 1987-04-18 2019-11-03 01:35:00  115163   10.125
# 7        NaN  Female 2015-07-20 2019-11-03 10:43:00   45906   11.598
#
#    Senior Management       Team
# 0               True  Marketing
# 2              False    Finance
# 3               True    Finance
# 5              False      Legal
# 7               True    Finance

# %%
mask1 = df["Team"].isin(["Marketing", "Finance", "Legal"]) 
mask2 = df["First Name"].isin(["Douglas", "Maria", "James"])
df[mask1 & mask2].head()
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2019-11-03 12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23 2019-11-03 11:17:00  130590   11.858
# 159      James     NaN 1983-11-22 2019-11-03 22:52:00   68501   14.316
# 667    Douglas     NaN 2009-02-04 2019-11-03 02:03:00  104496   14.771
# 668      James    Male 2001-12-05 2019-11-03 07:06:00   67789   17.105
#
#      Senior Management       Team
# 0                 True  Marketing
# 2                False    Finance
# 159              False  Marketing
# 667               True  Marketing
# 668               True      Legal

# %%
#Where People are not in Marketing, Finance, Legal
mask1 = df["Team"].isin(["Marketing", "Finance", "Legal"]) 
mask2 = df["First Name"].isin(["Douglas", "Maria", "James"])
df[~mask1 & mask2].head()
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 91       James     NaN 2005-01-26 2019-11-03 23:00:00  128771    8.309
# 198      Maria  Female 1990-12-27 2019-11-03 21:57:00   36067    9.640
# 217    Douglas    Male 1999-09-03 2019-11-03 16:00:00   83341    1.015
# 301      James    Male 2015-07-11 2019-11-03 20:52:00   72257   13.023
# 322    Douglas    Male 2002-01-08 2019-11-03 18:42:00   41428   14.372
#
#      Senior Management             Team
# 91               False              NaN
# 198               True          Product
# 217               True  Client Services
# 301              False      Engineering
# 322              False          Product

# %% [markdown]
# ## .isnull() and .notnull() Methods

# %%
#Let's filter data where people don't have their Genders defined
mask = df["Gender"].isnull()
len(df[mask])
df[mask].head()
# Out:
#    First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 20       Lois    NaN  4/22/1995         7:18 PM   64714    4.934
# 22     Joshua    NaN   3/8/2012         1:58 AM   90816   18.816
# 27      Scott    NaN  7/11/1991         6:58 PM  122367    5.218
# 31      Joyce    NaN  2/20/2005         2:40 PM   88657   12.752
# 41  Christine    NaN  6/28/2015         1:08 AM   66582   11.308
#
#    Senior Management                  Team
# 20              True                 Legal
# 22              True       Client Services
# 27             False                 Legal
# 31             False               Product
# 41              True  Business Development

# %%
#Let's filter data for people having valid Gender
mask = df["Gender"].notnull()
len(df[mask])
# Out:
# 855

# %% [markdown]
# ## .between() Method
# - by default values are inclusive

# %%
#Let's find the employees having salary between 50000 and 70000
mask = df["Salary"].between(50000, 70000)
df[mask].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1      Thomas    Male 1996-03-31 2019-11-03 06:53:00   61933    4.170
# 6        Ruby  Female 1987-08-17 2019-11-03 16:20:00   65476   10.012
# 10     Louise  Female 1980-08-12 2019-11-03 09:01:00   63241   15.132
# 15    Lillian  Female 2016-06-05 2019-11-03 06:09:00   59414    1.256
# 20       Lois     NaN 1995-04-22 2019-11-03 19:18:00   64714    4.934
#
#     Senior Management     Team
# 1                True      NaN
# 6                True  Product
# 10               True      NaN
# 15              False  Product
# 20               True    Legal

# %%
#Let's find employees who joined between 1996-01-01 and 1996-02-01
df[ df["Start Date"].between("1996-01-01", "1996-02-01") ]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 572    Raymond    Male 1996-01-13 2019-11-03 16:14:00  114244   16.690
# 916    Marilyn  Female 1996-01-16 2019-11-03 07:18:00  118369    7.696
#
#      Senior Management                  Team
# 572              False       Human Resources
# 916               True  Business Development

# %%
#Let's find the employees who logged in between 8:00 Am and 12:00 Pm
df[ df["Last Login Time"].between("8:00AM", "12:00PM") ].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2       Maria  Female 1993-04-23 2019-11-03 11:17:00  130590   11.858
# 7         NaN  Female 2015-07-20 2019-11-03 10:43:00   45906   11.598
# 10     Louise  Female 1980-08-12 2019-11-03 09:01:00   63241   15.132
# 18      Diana  Female 1981-10-23 2019-11-03 10:27:00  132940   19.082
# 33       Jean  Female 1993-12-18 2019-11-03 09:07:00  119082   16.180
#
#     Senior Management                  Team
# 2               False               Finance
# 7                True               Finance
# 10               True                   NaN
# 18              False       Client Services
# 33              False  Business Development

# %%
df[ df["First Name"].between("James", "Maria") ].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2       Maria  Female 1993-04-23 2019-11-03 11:17:00  130590   11.858
# 3       Jerry    Male 2005-03-04 2019-11-03 13:00:00  138705    9.340
# 4       Larry    Male 1998-01-24 2019-11-03 16:47:00  101004    1.389
# 10     Louise  Female 1980-08-12 2019-11-03 09:01:00   63241   15.132
# 11      Julie  Female 1997-10-26 2019-11-03 15:19:00  102508   12.637
#
#     Senior Management             Team
# 2               False          Finance
# 3                True          Finance
# 4                True  Client Services
# 10               True              NaN
# 11               True            Legal

# %% [markdown]
# ## .duplicated() method
# - depending on the argument 'keep', this function marks, 'first', 'last', or all entries as duplicated
# - keep = 'first' will mark first entry as non-duplicated, rest as duplicated
# - keep = 'last' will mark last entry as non-duplicated, rest as duplicated
# - keep = False will mark all as duplicated

# %%
df.sort_values(by = "First Name", inplace = True)

# %%
df.head(3)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2019-11-03 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2019-11-03 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2019-11-03 14:53:00   52119   11.343
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services

# %%
df["First Name"].duplicated().head(8)
# Out:
# 101    False
# 327     True
# 440     True
# 937     True
# 137    False
# 141     True
# 302     True
# 538     True
# Name: First Name, dtype: bool

# %%
df["First Name"].duplicated(keep = 'last').head(8)
# Out:
# 101     True
# 327     True
# 440     True
# 937    False
# 137     True
# 141     True
# 302     True
# 538    False
# Name: First Name, dtype: bool

# %%
df["First Name"].duplicated(keep = False).head(8)
# Out:
# 101    True
# 327    True
# 440    True
# 937    True
# 137    True
# 141    True
# 302    True
# 538    True
# Name: First Name, dtype: bool

# %%
#Extract all employees with duplicated names
df[df["First Name"].duplicated(keep = False)].head(10)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2019-11-03 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2019-11-03 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2019-11-03 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2019-11-03 19:39:00   63126   18.424
# 137       Adam   Male 2011-05-21 2019-11-03 01:45:00   95327   15.120
# 141       Adam   Male 1990-12-24 2019-11-03 20:57:00  110194   14.727
# 302       Adam   Male 2007-07-05 2019-11-03 11:59:00   71276    5.027
# 538       Adam   Male 2010-10-08 2019-11-03 21:53:00   45181    3.491
# 300       Alan   Male 1988-06-26 2019-11-03 03:54:00  111786    3.592
# 53        Alan    NaN 2014-03-03 2019-11-03 13:28:00   40341   17.578
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution
# 141               True          Product
# 302               True  Human Resources
# 538              False  Human Resources
# 300               True      Engineering
# 53                True          Finance

# %%
#Filter all unique employees (use of negation)
df[~ df["First Name"].duplicated(keep = False)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2019-11-03 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2019-11-03 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2019-11-03 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2019-11-03 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2019-11-03 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2019-11-03 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2019-11-03 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2019-11-03 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2019-11-03 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# 5                False                 Legal
# 495              False                 Sales
# 33               False  Business Development
# 832              False                 Legal
# 291               True       Client Services

# %%
#Filter all the first non duplicate employees
df[~df["First Name"].duplicated(keep = 'first')]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male   2/17/2012        10:20 AM   61602   11.849
# 137       Adam    Male   5/21/2011         1:45 AM   95327   15.120
# 300       Alan    Male   6/26/1988         3:54 AM  111786    3.592
# 372     Albert    Male    2/1/1997         4:20 PM   67827   19.717
# 988      Alice  Female   10/5/2004         9:34 AM   47638   11.209
# 639     Amanda     NaN   8/11/1991         2:15 PM   46665   19.391
# 879        Amy  Female   5/20/2009         6:26 AM   75415   19.132
# 430     Andrea  Female   10/1/2010        11:54 AM   79123   19.422
# 564     Andrew    Male   3/29/1985         6:57 PM   43414    7.563
# 8       Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 509        Ann  Female   11/4/1984        12:17 PM   90719    6.220
# 645       Anna     NaN   3/13/1985         9:19 AM   45418   10.162
# 262       Anne  Female   7/16/1986         2:08 PM   69134    3.723
# 87       Annie  Female   1/30/1993         2:05 AM  144887    8.276
# 886    Anthony    Male   1/30/2014         9:04 PM   96795   14.837
# 129    Antonio    Male  10/25/1988         1:50 PM   60866   13.101
# 556     Arthur    Male  12/16/2014         4:56 PM   66819    6.639
# 138     Ashley  Female   5/25/2006        11:30 AM  112238    6.030
# 735    Barbara  Female  11/26/2002         5:32 AM   82884    6.837
# 757   Benjamin    Male   4/12/1988        11:32 PM  123409    7.783
# 894      Betty  Female  11/19/2002        10:40 AM   37005    7.645
# 956    Beverly  Female  10/17/1986        12:51 AM   80838    8.115
# 838      Billy    Male    4/6/2000         3:14 PM  115280    9.153
# 776      Bobby    Male   9/30/2004        10:52 PM   79047   18.784
# 79      Bonnie  Female  11/13/1988         3:30 PM  115814    4.990
# 892    Brandon    Male  10/23/1995        12:04 PM   60263    2.709
# 872     Brenda  Female   1/18/2015         4:39 PM   73749   19.332
# 688      Brian    Male    4/7/2007        10:47 PM   93901   17.821
# 604      Bruce    Male   3/15/2013        11:13 PM  141335   15.427
# 282       Carl     NaN    2/7/2014         3:57 AM  125104   12.345
# ..         ...     ...         ...             ...     ...      ...
# 696     Samuel    Male   5/25/2012         4:40 PM   85550   11.593
# 589     Sandra  Female   4/24/1995         7:14 PM  116931    9.657
# 882       Sara     NaN  11/18/2014         2:47 PM  135990   14.344
# 417      Sarah     NaN   8/31/1981         2:51 PM   37748    9.047
# 452      Scott    Male  11/17/2012         2:47 PM  146812    1.965
# 501       Sean    Male   2/11/2013         7:07 PM   42748    9.765
# 489     Sharon  Female    7/1/2011         9:50 AM   46007   19.731
# 804      Shawn    Male   3/17/2008         2:12 PM   39335   10.664
# 130    Shirley  Female    5/1/1984         1:15 PM   41334    6.219
# 475  Stephanie  Female  11/26/1992        12:54 AM  122121    7.937
# 756    Stephen    Male  10/21/1984         6:26 AM  121816   10.615
# 525      Steve    Male   8/22/1995         6:58 AM   67780    9.540
# 743     Steven    Male   5/30/1980         8:25 PM  100949   13.813
# 975      Susan  Female    4/7/1995        10:05 PM   92436   12.467
# 291      Tammy  Female  11/11/1984        10:30 AM  132839   17.463
# 613     Teresa     NaN    1/3/1992         3:47 PM   63103   11.378
# 762      Terry    Male  11/10/2004         4:33 AM   35633    3.947
# 795    Theresa     NaN   10/7/1995        10:16 AM   42025    3.319
# 967     Thomas    Male   3/12/2016         3:10 PM  105681   19.572
# 664    Timothy    Male   10/6/2010        10:49 PM   49473   12.463
# 113       Tina  Female   6/12/2009         7:16 AM  114767    3.711
# 609       Todd    Male   2/16/2010        11:29 AM  103405   15.910
# 422     Victor    Male   9/24/2005        12:04 PM  123144   16.261
# 294   Virginia  Female  10/20/1999         6:23 AM   46905   19.154
# 288     Walter     NaN  12/21/1999        10:33 PM   66757   18.099
# 433      Wanda  Female   7/20/2008         1:44 PM   65362    7.132
# 177      Wayne    Male    4/7/2012         8:00 AM  102652   14.085
# 820    William    Male  11/18/1993        12:27 PM   54058    5.182
# 450     Willie    Male   8/22/2009         1:03 PM   55038   19.691
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
#
#     Senior Management                  Team
# 101              True             Marketing
# 137             False          Distribution
# 300              True           Engineering
# 372              True           Engineering
# 988             False       Human Resources
# 639              True       Client Services
# 879             False       Client Services
# 430             False          Distribution
# 564              True       Client Services
# 8                True           Engineering
# 509             False  Business Development
# 645             False             Marketing
# 262              True           Engineering
# 87               True                 Sales
# 886             False                 Sales
# 129              True  Business Development
# 556              True             Marketing
# 138              True           Engineering
# 735              True  Business Development
# 757             False               Product
# 894              True             Marketing
# 956             False           Engineering
# 838             False          Distribution
# 776             False       Human Resources
# 79              False               Product
# 892             False                 Sales
# 872             False  Business Development
# 688              True                 Legal
# 604              True           Engineering
# 282             False       Client Services
# ..                ...                   ...
# 696              True             Marketing
# 589              True       Human Resources
# 882              True          Distribution
# 417             False       Human Resources
# 452              True             Marketing
# 501             False          Distribution
# 489              True       Client Services
# 804             False          Distribution
# 130              True       Human Resources
# 475              True           Engineering
# 756              True          Distribution
# 525              True       Human Resources
# 743              True       Human Resources
# 975             False                 Sales
# 291              True       Client Services
# 613             False               Finance
# 762              True          Distribution
# 795              True       Human Resources
# 967             False           Engineering
# 664             False                 Legal
# 113              True           Engineering
# 609             False                 Sales
# 422              True               Product
# 294             False          Distribution
# 288             False          Distribution
# 433              True                 Legal
# 177              True          Distribution
# 820              True       Human Resources
# 450             False                 Legal
# 7                 NaN               Finance
#
# [201 rows x 8 columns]

# %%
df.drop_duplicates(subset = ["First Name"], keep = False)
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2019-11-03 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2019-11-03 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2019-11-03 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2019-11-03 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2019-11-03 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2019-11-03 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2019-11-03 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2019-11-03 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2019-11-03 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# 5                False                 Legal
# 495              False                 Sales
# 33               False  Business Development
# 832              False                 Legal
# 291               True       Client Services

# %%
df["Gender"].unique()
# Out:
# 2
